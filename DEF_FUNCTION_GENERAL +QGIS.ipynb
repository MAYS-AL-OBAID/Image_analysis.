# %%
def hello():
    print('hello world')
hello()
# Out:
# hello world

# %%
def my_name():
    print('my name is m')
my_name()
# Out:
# my name is m

# %%
def print_number():
    print('10')
print_number()
# Out:
# 10

# %%
def greet(name):
    print('hello', name)

greet('sara')
# Out:
# hello sara

# %%
def square(number):
    print(number ** 2)
square(4)
# Out:
# 16

# %%
def age(age1):
    print(age1 + 5)
age(32)
# Out:
# 37

# %%
def add(a, b):
    print(a + b)

add(5, 5)
# Out:
# 10

# %%
def full_name(first, last):
    print(first, last)
full_name('may','asd')
# Out:
# may asd

# %%
def average(a, b):
    print(a+b/2)
average(5, 6)
# Out:
# 8.0

# %%
 
def multiply(a, b):
    return a * b
multiply(4, 5)
# Out:
# 20

# %%
def cube(a):
    return a **3
cube(4)
# Out:
# 64

# %%
def sum_three(a, b, c):
    return a +b +c

sum_three(3,4,5)
# Out:
# 12

# %%
def double(a):
    return a**2


c = double(3) 
print(c)
# Out:
# 9

# %%
def circle_area(r):
    pi = 3.14
    return r*pi*r

circle_area(5)
# Out:
# 78.5

# %%
def cal_tot(price, tax):

    return price +(price * tax)
cal_tot(1000, 0.700)
# Out:
# 1700.0

# %%
def sec_min(seconds):
    return seconds / 60

sec_min(300)
# Out:
# 5.0

# %%
def is_even(number):
    if number % 2 ==0:
        return True

    else:
        return False

is_even(17)
# Out:
# False

# %%
def active_layer(name1, name2, name3):
    return name1, name2, name3

active_layer('school', 'm', 'b')
# Out:
# ('school', 'm', 'b')

# %%
def active_layer(): 
    print('qgis script started')

active_layer()
# Out:
# qgis script started

# %%
def layer_name(l):
    print(l)
layer_name('road')
# Out:
# road

# %%
def feature_info(feature_name, area):
    print(f'feature: {feature_name} | area: {area}')
feature_info('road', 488)
# Out:
# feature: road | area: 488

# %%
def classify(area):
    if area > 1000:
        #return 'large'
        print(f' this area its larger than 1000 so its large')

    else:
        #return 'small'
        print('small')

classify(600)
classify(50000)
classify(3000000)
# Out:
# small
#  this area its larger than 1000 so its large
#  this area its larger than 1000 so its large

# %%
#FOR LOOP
#y = []
#for x in y :
#    print(X)

#DEF FUNCTION
#def fun(g):
#    print('g')
#fun(4)


def fun(names):
    for features in names:
        print(features)

#names=['lake', 'road', 'street']

#fun(names)



fun(['road', 'lake', 'street']) # THE SAME RESULTS
# Out:
# road
# lake
# street

# %%
def fun(name):
    print('the layer name is', name)

fun('lake')
fun('road')
fun('hhhh')
# Out:
# the layer name is lake
# the layer name is road
# the layer name is hhhh

# %%
def fun():
    return('EPSQ:6754')

print(fun())
# Out:
# EPSQ:6754

# %%
def fun(feature):
    return(feature['area'])

feature = {'name':100, 'area':'river'}

fun(feature)
# Out:
# 'river'

# %%
city ={'name': 'padova', 'population': 140000000} 

def fun(city):
    return(city['population'])


fun(city)
# Out:
# 140000000

# %%
student={'name': 'ali', 'grade': 77}
def fun(student):
    return(student['grade'])

fun(student)
# Out:
# 77

# %%
features = {'country': 'italy', 'population': 12334444444}

def fun(features):
    return(features['country'])

fun(features)
# Out:
# 'italy'

# %%
def fun(buffer):
    return buffer * 2

fun(10)
# Out:
# 20

# %%
def fun(area):
    if area> 100:
        return('large')

    else:
        return('small')

print(fun(10))
print(fun(1000000))
# Out:
# small
# large

# %%
def fun(count):
    if count == 0:
        return True
    else:
        return False


fun(0)
fun(100)
fun(0)
# Out:
# True

# %%
def fun():
    return 'polygon'


print(fun())
# Out:
# polygon

# %%
#area1 =[200]
#area2 =[600]

def fun(area1, area2):

    if area1 > area2:
    
        return 'the area 1 its bigger'

    else:
        return 'the area 1 its small than area 2'



print(fun(200, 600))
# Out:
# the area 1 its small than area 2

# %%
def fun(new_layer):
    return new_layer + 'buffer'

print(fun('roads_'))
# Out:
# roads_buffer

# %%
def layer_summery(account, name):
    return (f'layer {account} {name} contains 25 features')

print(layer_summery('lake', 'road'))
# Out:
# layer lake road contains 25 features
