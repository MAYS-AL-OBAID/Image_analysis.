# %%
import numpy as np
data = np.array([2,3,4,5,6,7])
y = np.mean(x)
print(y)
# Out:
# 4.5

# %%
import pandas as pd

table = {'year':[2010, 2012,2013,2014],
         'data':[3.0, 6.4, 7.8,4.3]}

x = pd.DataFrame(table)

print (x)
# Out:
#    year  data
# 0  2010   3.0
# 1  2012   6.4
# 2  2013   7.8
# 3  2014   4.3

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [10,20,30,40,50,60]

plt.plot(x,y)
plt.show()
